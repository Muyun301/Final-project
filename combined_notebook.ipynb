# %% [markdown]
# # Group Notebook
#
# ## Introduction
# [placeholder]
#
# ## The Metric
# We define the best neighborhood as the one with the lowest final score.
# The final score will be calcluated by summing the individual rankings for each neighborhood across the three sub-metrics.
# The neighborhood with the least combined score would be considered the best neighborhood.
# ### Submetrics
# #### Submetric 1: Median Income Difference
# [explaining this submetric]
# #### Submetric 2: Speeding Percentage
# [explaining this submetric]
# #### Submetric 3: Placeholder
# [explaining this submetric]

# %%
# [the code that did the math]

# %% [markdown]
# ## Conclusion
#
# The best neighborhood factoring in all the submetrics was: XXXXXXX.
